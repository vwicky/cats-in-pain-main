# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="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"
)

completion = client.chat.completions.create(
    model="anthropic/claude-3-haiku",
    messages=[
        {"role": "system", "content": "You are a helpful evaluator."},
        {"role": "user", "content": "Evaluate this answer: ..."}
    ]
)

print(completion.choices[0].message.content)
# Out:
# I'm afraid I don't have enough context to evaluate the answer you provided. Could you please share the full question or prompt so I can better understand the context and provide a more informed evaluation?
